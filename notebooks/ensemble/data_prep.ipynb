# %% [markdown]
# Note: Remember to update latest change in `data_prep.py`, this is for testing purposes

# %% [markdown]
# ### Data Loaders
# data_loader_v1:
# - parameters:
#   - `feature_type`:
#   - `val`: True/False, if `val=True`, will return 3 datasets (Train, Val, Test); if `val=False`, will only return 2 datasets (Train, Test)
#   - `scale`: Optional, if `scale=True`, the features will be standardized using a `scaler`. The function scales the training set, and the same scaler is applied to the validation and test sets to ensure consistency
#   - `base_dir`: essentially, it's folder name, eg: `{base_dir}/train.txt`, `{base_dir}/final_labels.csv`, `{base_dir}/Xy_{feature_type}.npy`

# %% [markdown]
# ### Input and Output
# Input files:
# - `txt` files: `train.txt`, `test.txt`, `valid.txt`
# - `xlsx` file: dataset labels
# - `npy` file: Pre-processed dataset (will split according to the `txt` files)
#
# Output files:
# - `np arrays` (Tuple):
#   - if `val=True`, return Train (`train_x`, `train_y`), Val (`val_x`, `val_y`), Test (`test_x`, `test_y`)
#   - else, return Train (`train_x`, `train_y`), Test (`test_x`, `test_y`)
#
# Example:\
# a `data_loader_v1()` with `val=True` can be called as:\
# `train, val, test = data_loader_v1(feature_type, val=True)`\
# where it can be further splitted into x, y: `train_x, train_y = train`, `test_x, test_y = test`, `val_x, val_y = val`

# %% [markdown]
# ### Data-entries check
# Variables:
# - `features_label_map`: A dictionary maps a key to a tuple (feat)
# - `trainXy`,`valXy`,`testXy`: Lists contain key for each data point in the corresponding split (train, validation, test), the function attempts to look up each identifier in the `features_label_map`
#
# Explanation:
# - "not found error" will occur in `data_loader_v1`, refers to entries in `trainXy`, `valXy` or `testXy` that are missing from `features_label_map`
# - can check successfully processed data with: `print(len(train[0]),len(val[0]),len(test[0]))`
#
# Goal:
# - Ensure that all total errors are 0

# %%
import os
import glob
import utils
import config

import numpy as np
import pandas as pd
from tqdm import tqdm

from sklearn.preprocessing import normalize
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler() 

n_segments = config.N_SEGMENTS

# %% [markdown]
# ### Double Dataloader (Openface + Marlin)

# %%
# Openface + Marlin Dataloader
def data_loader_fusion(feature_type, val=True, base_dir='EmotiW2023 Data Small'):
    labels = pd.read_excel(f'{base_dir}/engagement_labels.xlsx', index_col=0) # Load label file
    print(labels.head())
    
    Xy = np.load(f'{base_dir}/Xy_{feature_type}.npy', allow_pickle=True)
    print(type(Xy), len(Xy))
    
    features_label_map = {}
    for xy in Xy:  
        features_label_map[xy[0]] = (xy[1], xy[2], xy[3])
    
    train_x_1 = []
    train_x_2 = []
    train_y = []
    if val:
        val_x_1 = []
        val_x_2 = []
        val_y = []
        
    test_x_1 = []
    test_x_2 = []
    test_y = []

    train_not_found_count = 0
    val_not_found_count = 0
    test_not_found_count = 0
    
    trainXy = utils.read_file(f'{base_dir}/train.txt')
    testXy = utils.read_file(f'{base_dir}/test.txt')
    valXy = utils.read_file(f'{base_dir}/valid.txt')
    print('TrainXy:', trainXy[:5])
    print('len TrainXy:', len(trainXy))
    print('TestXy:', testXy[:5])
    print('len TestXy:', len(testXy))
    print('ValXy:', valXy[:5])
    print('len ValXy:', len(valXy))

    # Training loop
    for e in trainXy:
        try:
            xy = features_label_map[e]
            if xy[2] != config.SNP:
                train_x_1.append(xy[0])
                train_x_2.append(xy[1])
                train_y.append(config.LABEL_MAP[xy[2]])
        except KeyError as k:
            print ('not found(train): ', k)
            train_not_found_count += 1
            # pass

    # Apply scaling
    X = np.array(train_x_2)
    scaler.fit(X.reshape(-1, X.shape[-1]))
    for i in range(len(train_x_2)):
        train_x_2[i] = scaler.transform(train_x_2[i])

    # Validation loop
    for e in valXy:
        try:
            xy = features_label_map[e]
            if xy[2] != config.SNP:
#                     
                x = xy[1]
                
                x = scaler.transform(xy[1])
                if val:
                    val_x_2.append(x)
                    val_x_1.append(xy[0])
                    val_y.append(config.LABEL_MAP[xy[2]])
                else:
                    train_x_1.append(xy[0])
                    train_x_2.append(x)
                    train_y.append(config.LABEL_MAP[xy[2]])
        except KeyError as k:
            print ('not found(val): ', k)
            val_not_found_count += 1
            # pass
#                 print ('not found(val): ', k)

    # Test loop
    for e in testXy:
        try:
            xy = features_label_map[e]
            if xy[2] != config.SNP:
                
                x = xy[1]
                
                x = scaler.transform(xy[1])
                
                test_x_1.append(xy[0])
                test_x_2.append(x)
                test_y.append(config.LABEL_MAP[xy[2]])
        except KeyError as k:
            print ('not found(test): ', k)
            test_not_found_count += 1
            # pass
#             print ('not found(test): ', k)
    if val:
        return (
            ((np.array(train_x_1), np.array(train_x_2)), np.array(train_y)), 
            ((np.array(val_x_1), np.array(val_x_2)), np.array(val_y)), 
            ((np.array(test_x_1), np.array(test_x_2)), np.array(test_y))
        )
    else:
        return (
            ((np.array(train_x_1), np.array(train_x_2)), np.array(train_y)), 
            ((np.array(test_x_1), np.array(test_x_2)), np.array(test_y))
            )

# %% [markdown]
# ### Single Dataloader (Openface or Marlin only)

# %%
# Openface Dataloader
def data_loader_v1(feature_type, val=True, scale=False, base_dir='EmotiW2023 Data Small'):
    
    """Data load without having separate npy files for splits
    """
    labels = pd.read_excel(f'{base_dir}/engagement_labels.xlsx', index_col=0) # Load label file
    print(labels.head())

    # Load individual dataset (Openface or Marlin)
    Xy = np.load(f'{base_dir}/Xy_{feature_type}.npy', allow_pickle=True) # Load npy file
    
    Xy = utils.cleanXy(Xy)
    print(type(Xy), len(Xy))

    features_label_map = {}
    for xy in Xy:  
        features_label_map[xy[0]] = (xy[1], xy[2])
        
    train_x = []
    train_y = []
    if val:
        val_x = []
        val_y = []
        
    test_x = []
    test_y = []
    
    trainXy = utils.read_file(f'{base_dir}/train.txt')
    testXy = utils.read_file(f'{base_dir}/test.txt')
    valXy = utils.read_file(f'{base_dir}/valid.txt')
    print('TrainXy:', trainXy[:5])
    print('len TrainXy:', len(trainXy))
    print('TestXy:', testXy[:5])
    print('len TestXy:', len(testXy))
    print('ValXy:', valXy[:5])
    print('len ValXy:', len(valXy))

    # Debugging
    print("trainXy sample:", trainXy[:5])
    print("features_label_map keys sample:", list(features_label_map.keys())[:5])

    # Initialize error counters
    train_not_found_count = 0
    val_not_found_count = 0
    test_not_found_count = 0

    # Training loop
    for e in trainXy:
        try:
            xy = features_label_map[e]
            if xy[1] != config.SNP:
                train_x.append(xy[0])
                train_y.append(config.LABEL_MAP[xy[1]])
        except KeyError as k:
            print ('not found(train): ', k)
            train_not_found_count += 1
            # pass             
    if scale:    
        X = np.array(train_x)
        scaler.fit(X.reshape(-1, X.shape[-1]))
        for i in range(len(train_x)):
            train_x[i] = scaler.transform(train_x[i]) 

    # Validation loop
    for e in valXy:
        try:
            xy = features_label_map[e]
            if xy[1] != config.SNP:
                     
                x = xy[0]
                if scale:
                    x = scaler.transform(xy[0])
                if val:
                    val_x.append(x)
                    val_y.append(config.LABEL_MAP[xy[1]])
                else:
                    train_x.append(x)
                    train_y.append(config.LABEL_MAP[xy[1]])
        except KeyError as k:
            #pass
            print ('not found(val): ', k)
            val_not_found_count += 1

    # Test loop
    for e in testXy:
        try:
            xy = features_label_map[e]
            if xy[1] != config.SNP:                
                x = xy[0]
                if scale:
                    x = scaler.transform(xy[0])
                test_x.append(x)
                test_y.append(config.LABEL_MAP[xy[1]])
        except KeyError as k:
            #pass
            print ('not found(test): ', k)
            test_not_found_count += 1

    # Print total not found counts
    print(f"Total not found in train: {train_not_found_count}")
    print(f"Total not found in validation: {val_not_found_count}")
    print(f"Total not found in test: {test_not_found_count}")

    if val:
        return ((np.array(train_x), np.array(train_y)), 
                (np.array(val_x), np.array(val_y)), 
                (np.array(test_x), np.array(test_y)))
    else:
        return ((np.array(train_x), np.array(train_y)), 
                (np.array(test_x), np.array(test_y)))

# %% [markdown]
# ### Main Execution
# Basic test cases are executed:
# - Verify shapes of loaded data, make sure its loaded correctly

# %%
if __name__ == '__main__':

    print ("testing data prep")
    feature_type = config.MARLIN  # selections: GAZE_HP_AU, FUSION, MARLIN
    train, val, test = data_loader_v1(feature_type, val=True)  # data_loader_v1, data_loader_fusion
    train_x, train_y = train
    test_x, test_y = test
    val_x, val_y = val
    print(len(train_x[0]), len(train_y), len(test_x[0]), len(test_y), len(val_x[0]), len(val_y))
# Out:
# testing data prep
#                                 chunk           label
# 0   subject_68_0ng3yqwrg6_vid_0_0.mp4         Engaged
# 1   subject_68_0ng3yqwrg6_vid_0_1.mp4  Highly-Engaged
# 2  subject_68_0ng3yqwrg6_vid_0_10.mp4  Highly-Engaged
# 3  subject_68_0ng3yqwrg6_vid_0_11.mp4  Highly-Engaged
# 4  subject_68_0ng3yqwrg6_vid_0_12.mp4         Engaged
# <class 'numpy.ndarray'> 7670
# TrainXy: ['subject_68_0ng3yqwrg6_vid_0_0.mp4', 'subject_68_0ng3yqwrg6_vid_0_1.mp4', 'subject_68_0ng3yqwrg6_vid_0_10.mp4', 'subject_68_0ng3yqwrg6_vid_0_11.mp4', 'subject_68_0ng3yqwrg6_vid_0_12.mp4']
# len TrainXy: 5752
# TestXy: ['subject_96_dh18u00dyu_vid_0_0.mp4', 'subject_96_dh18u00dyu_vid_0_1.mp4', 'subject_96_dh18u00dyu_vid_0_10.mp4', 'subject_96_dh18u00dyu_vid_0_11.mp4', 'subject_96_dh18u00dyu_vid_0_12.mp4']
# len TestXy: 1698
# ValXy: ['subject_85_rda0o4n8zs_vid_0_0.mp4', 'subject_85_rda0o4n8zs_vid_0_1.mp4', 'subject_85_rda0o4n8zs_vid_0_10.mp4', 'subject_85_rda0o4n8zs_vid_0_11.mp4', 'subject_85_rda0o4n8zs_vid_0_12.mp4']
# len ValXy: 892
# not found(train):  'subject_2_thw33jke4j_vid_1_33.mp4'
# not found(train):  'subject_2_thw33jke4j_vid_1_35.mp4'
# not found(train):  'subject_2_thw33jke4j_vid_1_36.mp4'
# not found(train):  'subject_2_thw33jke4j_vid_1_37.mp4'
# not found(train):  'subject_7_as2uk9lhe2_vid_0
mp4'
# not found(val):  'subject_124_zw8quy4q8v_vid_1_16.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_10.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_12.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_13.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_15.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_6.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_7.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_8.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_1_9.mp4'
# not found(val):  'subject_111_z2gx0nezbr_vid_2_30.mp4'
# not found(val):  'subject_107_t9w4xfx125_vid_0_2.mp4'
# not found(val):  'subject_107_t9w4xfx125_vid_0_3.mp4'
# not found(val):  'subject_107_t9w4xfx125_vid_2_11.mp4'
# not found(val):  'subject_107_t9w4xfx125_vid_2_12.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_0_16.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_0_17.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_0_18.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_10.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_11.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_14.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_15.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_18.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_21.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_32.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_33.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_8.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_1_9.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_0.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_10.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_11.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_12.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_15.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_16.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_17.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_21.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_22.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_6.mp4'
# not found(val):  'subject_5_3b5pqp1ldd_vid_2_8.mp4'
# not found(val):  'subject_92_fsvu5p8jub_vid_2_18.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_0_6.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_25.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_26.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_27.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_28.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_29.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_30.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_33.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_38.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_39.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_40.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_43.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_44.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_45.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_1_46.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_11.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_12.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_13.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_14.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_17.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_18.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_24.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_25.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_26.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_27.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_4.mp4'
# not found(test):  'subject_54_randomwxt0zmhpa6_vid_2_8.mp4'
# not found(test):  'subject_24_35aqq1f9lo_vid_1_13.mp4'
# not found(test):  'subject_24_35aqq1f9lo_vid_2_4.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_13.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_17.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_23.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_20.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_21.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_22.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_27.mp4'
# not found(test):  'subject_110_gc43xphq2h_vid_1_25.mp4'
# not found(test):  'subject_110_gc43xphq2h_vid_2_2.mp4'
# not found(test):  'subject_110_gc43xphq2h_vid_2_3.mp4'
# not found(test):  'subject_81_o0y9nap1wf_vid_1_17.mp4'
# not found(test):  'subject_81_o0y9nap1wf_vid_2_15.mp4'
# not found(test):  'subject_81_o0y9nap1wf_vid_2_7.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_0_3.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_0_4.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_0_5.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_0_6.mp4'
# 5444 5444 1640 1640 848 848

# %%
len(train_x[0])
# Out:
# 5444

# %%
if __name__ == '__main__':

    print ("testing data prep")
    feature_type = config.GAZE_HP_AU  # selections: GAZE_HP_AU, FUSION
    train, val, test = data_loader_v1(feature_type, val=True)
    train_x, train_y = train
    test_x, test_y = test
    val_x, val_y = val
    print(len(train_x), len(train_y), len(test_x), len(test_y), len(val_x), len(val_y))
# Out:
# testing data prep
#                                 chunk           label
# 0   subject_68_0ng3yqwrg6_vid_0_0.mp4         Engaged
# 1   subject_68_0ng3yqwrg6_vid_0_1.mp4  Highly-Engaged
# 2  subject_68_0ng3yqwrg6_vid_0_10.mp4  Highly-Engaged
# 3  subject_68_0ng3yqwrg6_vid_0_11.mp4  Highly-Engaged
# 4  subject_68_0ng3yqwrg6_vid_0_12.mp4         Engaged
# <class 'list'> 7664
# TrainXy: ['subject_68_0ng3yqwrg6_vid_0_0.mp4', 'subject_68_0ng3yqwrg6_vid_0_1.mp4', 'subject_68_0ng3yqwrg6_vid_0_10.mp4', 'subject_68_0ng3yqwrg6_vid_0_11.mp4', 'subject_68_0ng3yqwrg6_vid_0_12.mp4']
# len TrainXy: 5752
# TestXy: ['subject_96_dh18u00dyu_vid_0_0.mp4', 'subject_96_dh18u00dyu_vid_0_1.mp4', 'subject_96_dh18u00dyu_vid_0_10.mp4', 'subject_96_dh18u00dyu_vid_0_11.mp4', 'subject_96_dh18u00dyu_vid_0_12.mp4']
# len TestXy: 1698
# ValXy: ['subject_85_rda0o4n8zs_vid_0_0.mp4', 'subject_85_rda0o4n8zs_vid_0_1.mp4', 'subject_85_rda0o4n8zs_vid_0_10.mp4', 'subject_85_rda0o4n8zs_vid_0_11.mp4', 'subject_85_rda0o4n8zs_vid_0_12.mp4']
