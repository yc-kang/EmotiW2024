# %% [markdown]
# Note: This is for single fusion model
#
# ### Train Single
# Data:
# - `config.GAZE_HP_AU`: Openface
# - `config.MARLIN`: Marlin
# - `config.MEDIAPIPE`: Mediapipe
# - `config.VIDEOLLAVA`: Videollava

# %% [markdown]
# ### Model Details
#
# Details:
# - It uses a single modality model training, for testing purposes
# - It uses `data_loader_v1` in `data_prep.py`
# - It uses `transformer` model for ensembling
# - Make sure `npy` data file is preprocessed, before model training

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import normalize
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()

from keras.layers import Flatten, Concatenate, LSTM, Dense, Conv2D, Conv3D, GlobalAveragePooling1D, Dropout, MaxPooling2D

from tensorflow import keras
from tensorflow.keras import layers

from data_prep import data_loader_v1, data_loader_fusion
import config
import utils

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        self.mask_layer = MaskComputationLayer()  # Use the new mask layer

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return self.mask_layer(inputs)  # Use the mask layer to compute mask
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "sequence_length": self.sequence_length,
            "output_dim": self.output_dim
        })
        return config

class MaskComputationLayer(layers.Layer):
    def call(self, inputs):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), 
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "dense_dim": self.dense_dim,
            "num_heads": self.num_heads
        })
        return config

def build_user_model(x, input_shape, num_heads, mlp_units, mlp_dropout):
    dense_dim = 8
    embed_dim = input_shape[1]
    
    x = PositionalEmbedding(
        input_shape[0], embed_dim, name="frame_position_embedding_usr"
    )(x)
    
    
#     x = keras.layers.GlobalMaxPooling1D()(x)
    x = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)
    x = keras.layers.GlobalMaxPooling1D()(x)
    
#     # late fusin
#     for dim in mlp_units:
#         x = layers.Dense(dim, activation="relu")(x)
#         x = layers.Dropout(mlp_dropout)(x)
        
#     x = layers.Dense(4, activation='softmax')(x)
    return x

def build_stm_model(x, input_shape, num_heads, mlp_units, mlp_dropout):
    dense_dim = 8
    embed_dim = input_shape[1]
    
    x = PositionalEmbedding(
        input_shape[0], embed_dim, name="frame_position_embedding_stm"
    )(x)
    
  
    x = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)
    x = keras.layers.GlobalMaxPooling1D()(x)
    
#     # late fusing
#     for dim in mlp_units:
#         x = layers.Dense(dim, activation="relu")(x)
#         x = layers.Dropout(mlp_dropout)(x)
        
#     x = layers.Dense(4, activation='softmax')(x)
    return x

# def transformer_enc(
def transformer_encoder(inputs, head_size, num_heads, ff_dim=4, dropout=0.3):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs
    
    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_model(
        input_shape,
        head_size,
        num_heads,
        ff_dim,
        num_transformer_blocks,
        mlp_units,
        dropout=0,
        mlp_dropout=0,
        n_classes=4
    ):
    
    inputs = keras.Input(shape=input_shape)
    dense_dim = 8
    embed_dim = input_shape[1]
    
    x = PositionalEmbedding(
        input_shape[0], embed_dim, name="frame_position_embedding"
    )(inputs)
    
    x = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)

    x = layers.GlobalMaxPooling1D()(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation='softmax')(x)
    model = keras.Model(inputs, outputs)

    return model

# %%
BUFFER_SIZE = 100000

def make_ds(features, labels):
    ds = tf.data.Dataset.from_tensor_slices((features, labels))#.cache()
    ds = ds.shuffle(BUFFER_SIZE).repeat()
    return ds

def get_best_weights():
    import os
    def get_epoch(x):
        return int(x.split('epoch')[-1].split('-')[0])
    return sorted(os.listdir('./checkpoints/'), key=get_epoch)[-1]

def train(model_name, val=True):

    # use data_loader_v1 only
    data= data_loader_v1(model_name, val, scale=True)

    # edited for single data use
    if len(data) == 3:
        train, val, test = data
        val_x, val_y = val
    else:
        train, test = data
        
    train_x, train_y = train
    test_x, test_y = test
    
    total = train_y.shape[0]
    
    print ("train stats: ")
    print (train_x.shape, train_y.shape)
    
    if val:
        print ("val stats: ")
        print (val_x.shape, val_y.shape)
    
    print ("test stats: ")
    print (test_x.shape, test_y.shape)
    
    
    # class weight strategy
    class_weight = {
        k: (1 / train_y[train_y==k].shape[0]) * (total / 4) for k in np.unique(train_y)
    }
    
    
    BATCH_SIZE = 32
    
    input_shape = train_x.shape[1:]
        
    model = build_model(
        input_shape,
        head_size=256,
        num_heads=8,
        ff_dim=4,
        num_transformer_blocks=4,
        mlp_units=[128],
        mlp_dropout=0.5,
        dropout=0.3,
        n_classes=4
    )

    model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=keras.optimizers.Adam(learning_rate=1e-4),
        metrics=["accuracy"],
    )
    
    filepath = "checkpoints/" + model_name + ".epoch{epoch:02d}-acc{val_accuracy:.2f}.keras"
    checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')
    
    callbacks = [
                 keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True),
                 checkpoint
    ]
    if not val:
        val_x = test_x
        val_y = test_y
    
    model.fit(train_x, train_y, 
              validation_data=(val_x, val_y), 
              epochs=200, 
              callbacks=callbacks,
              )
    
    model.load_weights(f'checkpoints/{get_best_weights()}')
    print ("Evaluating on train set: ")
    model.evaluate(train_x, train_y)

    print ("Evaluating on valid set: ")
    model.evaluate(val_x, val_y)

    print ("Evaluating on test set: ")
    model.evaluate(test_x, test_y)

    y_pred_val = np.argmax(model.predict(val_x), axis=1)
    y_pred_test = np.argmax(model.predict(test_x), axis=1)
    
    print ("Classification report (val): ")
    print(classification_report(val_y, y_pred_val))
   
    print ("Classification report (test): ")
    print(classification_report(test_y, y_pred_test))

# %%
# import sys
import shutil, os
if __name__ == '__main__':
    shutil.rmtree('checkpoints/')
    os.mkdir('checkpoints')

    # Single data training
    train(config.MEDIAPIPE, val=True)  # MARLIN, GAZE_HP_AU, MEDIAPIPE
# Out:
#                                 chunk           label
# 0   subject_68_0ng3yqwrg6_vid_0_0.mp4         Engaged
# 1   subject_68_0ng3yqwrg6_vid_0_1.mp4  Highly-Engaged
# 2  subject_68_0ng3yqwrg6_vid_0_10.mp4  Highly-Engaged
# 3  subject_68_0ng3yqwrg6_vid_0_11.mp4  Highly-Engaged
# 4  subject_68_0ng3yqwrg6_vid_0_12.mp4         Engaged
# <class 'list'> 7773
mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_61.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_62.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_63.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_64.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_65.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_66.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_67.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_68.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_69.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_7.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_70.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_71.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_72.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_73.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_74.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_75.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_76.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_8.mp4'
# not found(train):  'subject_104_06lc4xlb48_vid_2_9.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_11.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_12.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_15.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_16.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_17.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_18.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_19.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_0_2.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_10.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_11.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_16.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_17.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_19.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_20.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_21.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_23.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_29.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_1_34.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_1.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_11.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_12.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_13.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_14.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_15.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_16.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_17.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_18.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_19.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_2.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_20.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_21.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_22.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_23.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_24.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_25.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_26.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_27.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_28.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_29.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_3.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_31.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_32.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_34.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_5.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_6.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_7.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_8.mp4'
# not found(train):  'subject_69_randomagje1dcmk3_vid_2_9.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_1.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_10.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_11.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_12.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_13.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_14.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_15.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_16.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_17.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_18.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_2.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_21.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_22.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_23.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_24.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_25.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_26.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_27.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_29.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_31.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_5.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_6.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_7.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_8.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_0_9.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_0.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_1.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_10.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_11.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_12.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_14.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_15.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_16.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_17.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_18.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_19.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_2.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_20.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_21.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_22.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_23.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_24.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_25.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_26.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_27.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_28.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_29.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_3.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_30.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_32.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_33.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_35.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_36.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_37.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_38.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_39.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_4.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_41.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_42.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_43.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_5.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_6.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_7.mp4'
# not found(train):  'subject_30_7ytx2foxy2_vid_1_9.mp4'
# not found(val):  'subject_124_zw8quy4q8v_vid_2_17.mp4'
# not found(val):  'subject_124_zw8quy4q8v_vid_2_19.mp4'
# not found(val):  'subject_92_fsvu5p8jub_vid_0_11.mp4'
# not found(val):  'subject_92_fsvu5p8jub_vid_0_2.mp4'
# not found(test):  'subject_24_35aqq1f9lo_vid_2_3.mp4'
# not found(test):  'subject_24_35aqq1f9lo_vid_2_4.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_12.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_13.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_14.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_15.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_16.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_17.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_18.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_19.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_20.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_21.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_22.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_23.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_24.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_0_25.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_0.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_1.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_18.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_1_19.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_2_10.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_2_11.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_2_16.mp4'
# not found(test):  'subject_103_xcjreth6q9_vid_2_22.mp4'
# not found(test):  'subject_61_9lo6k238pu_vid_0_1.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_0_27.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_0_30.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_1_31.mp4'
# not found(test):  'subject_15_randomdradnfzte6_vid_1_36.mp4'
# Total not found in train: 235
# Total not found in validation: 4
# Total not found in test: 29
# train stats:
# (5507, 20, 99) (5507,)
# val stats:
# (888, 20, 99) (888,)
# test stats:
# (1668, 20, 99) (1668,)
# WARNING:tensorflow:From C:\Python39\lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# C:\Python39\lib\site-packages\keras\src\layers\layer.py:391: UserWarning: `build()` was called on layer 'frame_position_embedding', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Epoch 1/200
# C:\Python39\lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'transformer_encoder' (of type TransformerEncoder) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# C:\Python39\lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'query' (of type EinsumDense) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# C:\Python39\lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'key' (of type EinsumDense) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# C:\Python39\lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'value' (of type EinsumDense) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3559 - loss: 1.8602
# Epoch 1: val_accuracy improved from -inf to 0.40428, saving model to checkpoints/engage_bodypose.epoch01-acc0.40.keras
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.3563 - loss: 1.8584 - val_accuracy: 0.4043 - val_loss: 1.3821
# Epoch 2/200
# 172/173 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4594 - loss: 1.3794
# Epoch 2: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.4595 - loss: 1.3794 - val_accuracy: 0.4043 - val_loss: 1.3777
# Epoch 3/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4598 - loss: 1.3736
# Epoch 3: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.4598 - loss: 1.3736 - val_accuracy: 0.4043 - val_loss: 1.3736
# Epoch 4/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4441 - loss: 1.3695
# Epoch 4: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.
val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4666 - loss: 1.2651 - val_accuracy: 0.4043 - val_loss: 1.3219
# Epoch 74/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4651 - loss: 1.2668
# Epoch 74: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4651 - loss: 1.2669 - val_accuracy: 0.4043 - val_loss: 1.3219
# Epoch 75/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4581 - loss: 1.2729
# Epoch 75: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4581 - loss: 1.2729 - val_accuracy: 0.4043 - val_loss: 1.3220
# Epoch 76/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4672 - loss: 1.2648
# Epoch 76: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4671 - loss: 1.2649 - val_accuracy: 0.4043 - val_loss: 1.3221
# Epoch 77/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4499 - loss: 1.2756
# Epoch 77: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.4501 - loss: 1.2755 - val_accuracy: 0.4043 - val_loss: 1.3221
# Epoch 78/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4592 - loss: 1.2727
# Epoch 78: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.4592 - loss: 1.2727 - val_accuracy: 0.4043 - val_loss: 1.3221
# Epoch 79/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4621 - loss: 1.2710
# Epoch 79: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.4621 - loss: 1.2710 - val_accuracy: 0.4043 - val_loss: 1.3222
# Epoch 80/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4507 - loss: 1.2822
# Epoch 80: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.4508 - loss: 1.2820 - val_accuracy: 0.4043 - val_loss: 1.3223
# Epoch 81/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4640 - loss: 1.2632
# Epoch 81: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4640 - loss: 1.2633 - val_accuracy: 0.4043 - val_loss: 1.3224
# Epoch 82/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4656 - loss: 1.2668
# Epoch 82: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4655 - loss: 1.2669 - val_accuracy: 0.4043 - val_loss: 1.3223
# Epoch 83/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4513 - loss: 1.2795
# Epoch 83: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4515 - loss: 1.2793 - val_accuracy: 0.4043 - val_loss: 1.3225
# Epoch 84/200
# 172/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4542 - loss: 1.2769
# Epoch 84: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4543 - loss: 1.2768 - val_accuracy: 0.4043 - val_loss: 1.3224
# Epoch 85/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4574 - loss: 1.2711
# Epoch 85: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.4575 - loss: 1.2711 - val_accuracy: 0.4043 - val_loss: 1.3225
# Epoch 86/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4498 - loss: 1.2779
# Epoch 86: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4500 - loss: 1.2778 - val_accuracy: 0.4043 - val_loss: 1.3225
# Epoch 87/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4588 - loss: 1.2691
# Epoch 87: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4588 - loss: 1.2692 - val_accuracy: 0.4043 - val_loss: 1.3226
# Epoch 88/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4496 - loss: 1.2842
# Epoch 88: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4498 - loss: 1.2840 - val_accuracy: 0.4043 - val_loss: 1.3226
# Epoch 89/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4574 - loss: 1.2726
# Epoch 89: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4575 - loss: 1.2726 - val_accuracy: 0.4043 - val_loss: 1.3226
# Epoch 90/200
# 171/173 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4610 - loss: 1.2694
# Epoch 90: val_accuracy did not improve from 0.40428
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4610 - loss: 1.2694 - val_accuracy: 0.4043 - val_loss: 1.3227
# Evaluating on train set:
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4895 - loss: 1.3802
# Evaluating on valid set:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4889 - loss: 1.3799
# Evaluating on test set:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6519 - loss: 1.3764
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Classification report (val):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       170
#            1       0.00      0.00      0.00       133
#            2       0.00      0.00      0.00       226
#            3       0.40      1.00      0.58       359
#
#     accuracy                           0.40       888
#    macro avg       0.10      0.25      0.14       888
# weighted avg       0.16      0.40      0.23       888
#
# Classification report (test):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       136
#            1       0.00      0.00      0.00       205
#            2       0.00      0.00      0.00       311
#            3       0.61      1.00      0.76      1016
#
#     accuracy                           0.61      1668
#    macro avg       0.15      0.25      0.19      1668
# weighted avg       0.37      0.61      0.46      1668
# C:\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
